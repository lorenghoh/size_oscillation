# %% [markdown]
# # Representations of size distribution
#
# Testing different representations of cloud size distribution.

# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import xarray as xr
import pandas as pd
import pyarrow.parquet as pq

# %%
from IPython.display import Image

# %% [markdown]
#  Sampling the 2-dimensional cross-sections:

# %%
Image('png/rep_2ds.png')

# %% [markdown]
#  On the other hand, we can sample the 3D volume by identifying contiguous areas of condensed liquid water.

# %%
Image('png/rep_3dv.png')

# %% [markdown]
#  And then take the horizontal cross-sections:

# %%
Image('png/rep_3ds.png')

# %% [markdown]
#  Let's stick with the contiguous volume. We can take a sample distribution and try to run the regression algorithms on the rank-size representation (upper right figure from the 4-panel plot above) and compare that to the 2D cross sections:

# %%
Image('png/outlier_detection_2ds.png')

# %%
Image('png/outlier_detection_3dv.png')

# %% [markdown]
# # Cloud Size Distribution
# ## Timeseries

# %%
Image('png/timeseries_3dv.png')

# %%
Image('png/plot_gaussian_reg.png')
