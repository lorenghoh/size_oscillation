# %%
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import xarray as xr
import pandas as pd
import pyarrow.parquet as pq

# %%
from IPython.display import Image

# %%
Image('../png/outlier_detection_sample.png')

# %%
Image('../png/plot_timeseries.png')

# %% [markdown]
# ## 12 hr Cloud vs Precipitation

# %%
Image('../png/BOMEX_12HR_ts_cloud_precip.png')

# %% [markdown]
# ## 12 hr Core vs Precipitation

# %%
Image('../png/BOMEX_12HR_ts_core_precip.png')

# %% [markdown]
# ## BOWL Cloud vs Precipitation

# %%
Image('../png/BOMEX_BOWL_ts_cloud_precip.png')

# %% [markdown]
# ## BOWL Core vs Precipitation

# %%
Image('../png/BOMEX_BOWL_ts_core_precip.png')

# %% [markdown]
# ## Gaussian Regression for BOWL dataset

# %%
Image('../png/plot_gaussian_reg.png')
